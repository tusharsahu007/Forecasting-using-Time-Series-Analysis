# %% [markdown]
# ## Internal Structures of Time Series:
# Please make sure that you are acquainted with the components of time series. Go through the blogs given below to brush up about them.
#
# **Trend:** In which there is no fixed interval and any divergence within the given dataset is a continuous timeline. The trend would be Negative or Positive or Null Trend
#
# **Seasonality:** In which regular or fixed interval shifts within the dataset in a continuous timeline. Would be bell curve or saw tooth
#
# **Cyclical:** In which there is no fixed interval, uncertainty in movement and its pattern
#
# **Irregularity:** Unexpected situations/events/scenarios and spikes in a short time span.
#
# Resources -
#
# ### 1. Trend
# * [What is a trend in time series?](https://www.geeksforgeeks.org/what-is-a-trend-in-time-series/)
# * [Trend graph](https://www.geeksforgeeks.org/plotting-a-trend-graph-in-python/)
# * [Mann-Kendall Trend Test](https://www.geeksforgeeks.org/how-to-perform-a-mann-kendall-trend-test-in-python/)
# * Read up about de-trending a time series using:
#   * Pandas Differencing Method
#   * [SciPy Signal](https://scipy-lectures.org/intro/scipy/auto_examples/plot_detrend.html)
#   * HP Filter
#
# ### 2. Seasonality
# * [What is seasonality?](https://www.investopedia.com/terms/s/seasonality.asp#:~:text=What%20Is%20Seasonality%3F,is%20said%20to%20be%20seasonal.)
# * [Identify and remove seasonality](https://machinelearningmastery.com/time-series-seasonality-with-python/)
# * Detecting seasonality using
#   * [Multiple Box Plots](https://www.mql5.com/en/articles/7038)
#   * [Autocorrelation Plots](https://www.mikulskibartosz.name/finding-seasonality-in-time-series-using-autocorrelation-plot/)
#   * [Other methods](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc443.htm)
# * Deseasoning of time series data - seasonal decomposition
# ### 3. Cyclicity
# A cyclic pattern exists when data exhibit rises and falls that are not of fixed period.
#
# Cyclical behavior on the other hand can drift over time because the time between periods isn’t precise. For example, the stock market tends to cycle between periods of high and low values, but there is no set amount of time between those fluctuations.
#
# A cyclic pattern exists when data exhibit rises and falls that are not of fixed period. The duration of these fluctuations is usually of at least 2 years. Think of business cycles which usually last several years, but where the length of the current cycle is unknown beforehand.
#
# * [Cyclic Variations](https://www.embibe.com/questions/What-is-cyclical-variation%3F/EM6194722)
# * Detecting Cyclic Variations
# * Extracting cyclic variations using an HP filter
#
# ### 4. Residuals
#
# **Residuals(e[t])** means an irregular variation of ts data.
#
# Referring to our model that expresses a time series as a sum of four components, it is
# noteworthy that in spite of being able to account for the three other components, we might
# still be left with an irreducible error component that is random and does not exhibit
# systematic dependency on the time index. This fourth component reflects unexpected
# variations in the time series. Unexpected variations are stochastic and cannot be framed in a
# mathematical model for a definitive future prediction. This type of error is due to lack of
# information about explanatory variables that can model these variations or due to presence
# of a random noise.
#
# When trend and cyclical variations are removed from time-series data, the
# patterns left behind that cannot be explained are called errors, unexpected
# variations, or residuals. Various methods are available to check for
# irregular variations such as probability theory, moving averages, and
# autoregressive time-series methods. If we can find any cyclic variation in
# data, it is considered to be part of the residuals. These variations that occur
# due to unexpected circumstances are called unexpected variations or
# unpredictable errors.
#
#
# * [Residual Diagnostics](https://otexts.com/fpp2/residuals.html)
# * [Plot of Residuals](https://narwadekrishna147.medium.com/plot-of-residuals-in-time-sequence-d0e5ece86a7c)
# * Videos related to Residuals in time series:
#   * https://youtu.be/KLazrM7hUao
#   * https://www.youtube.com/watch?v=RiaU4L1irog&ab_channel=Dr.ImranArif
#   * https://www.youtube.com/watch?v=oBa_H5aM7R0&ab_channel=apethan
